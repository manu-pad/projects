# %% [markdown]
# <div style="text-align: center; border: 1px solid black;">
#     <div style="display: inline-flex; justify-content: center; align-items: center; ">
#         <img src="https://www.di.ubi.pt/~rcampos/assets/img/ubi.jpg" alt="First Image" style="margin: 10px;"/>
#         <img src="https://www.di.ubi.pt/~rcampos/assets/img/DI_FE.jpg" alt="Second Image" style="margin: 10px;"/>
#     </div>
# </div>

# %% [markdown]
# <h3>Projeto 1</h3>
# <p>
#     Ciência de Dados em Larga Escala <br>
#     Beatriz Santos - 50473 | Manoela Azevedo - 50034 <br>
#     Docente: Ricardo Campos
# </p>

# %% [markdown]
# <h1>Indice<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#Introducao" data-toc-modified-id="Introducao"><span class="toc-item-num">1 -&nbsp;&nbsp;</span>Introdução</a></span>
#             <ul class="toc-item">
#                 <li><span><a href="#Divisao-de-trabalhos" data-toc-modified-id="Divisao-de-trabalhos"><span class="toc-item-num">1.1 -&nbsp;&nbsp;</span>Divisão de Trabalhos</a></span></li>
#                 <li><span><a href="#Declaracao" data-toc-modified-id="Declaracao"><span class="toc-item-num">1.2 -&nbsp;&nbsp;</span>Declaração</a></span></li>
#                 <li><span><a href="#Motivacao" data-toc-modified-id="Motivacao"><span class="toc-item-num">1.3 -&nbsp;&nbsp;</span>Motivação</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#Tarefa-1" data-toc-modified-id="Tarefa-1"><span class="toc-item-num">2 -&nbsp;&nbsp;</span>Tarefa 1</a></span>
#             <ul class="toc-item">
#                 <li><span><a href="#Tarefa-1.1" data-toc-modified-id="Tarefa-1.1"><span class="toc-item-num">2.1 -&nbsp;&nbsp;</span>Tarefa 1.1</a></span></li>
#                 <li><span><a href="#Tarefa-1.2" data-toc-modified-id="Tarefa-1.2"><span class="toc-item-num">2.2 -&nbsp;&nbsp;</span>Tarefa 1.2</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#Tarefa-2" data-toc-modified-id="Tarefa-2"><span class="toc-item-num">3 -&nbsp;&nbsp;</span>Tarefa 2</a></span>
#             <ul class="toc-item">
#                 <li><span><a href="#Tarefa-2.1" data-toc-modified-id="Tarefa-2.1"><span class="toc-item-num">3.1 -&nbsp;&nbsp;</span>Tarefa 2.1</a></span></li>
#                 <li><span><a href="#Tarefa-2.2" data-toc-modified-id="Tarefa-2.2"><span class="toc-item-num">3.2 -&nbsp;&nbsp;</span>Tarefa 2.2</a></span></li>
#                 <ul class="toc-item">
#                     <li><span><a href="#Pesquisa-tradicional" data-toc-modified-id="Pesquisa-tradicional"><span class="toc-item-num">3.2.1 -&nbsp;&nbsp;</span>Pesquisa Tradicional</a></span></li>
#                     <li><span><a href="#Pesquisa-com-queries" data-toc-modified-id="Pesquisa-com-queries"><span class="toc-item-num">3.2.2 -&nbsp;&nbsp;</span>Pesquisa com Queries</a></span></li>
#                     <li><span><a href="#Pesquisa-por-similaridade-de-vetor" data-toc-modified-id="Vetores-de-similaridade-com-BERT"><span class="toc-item-num">3.2.3 -&nbsp;&nbsp;</span>Pesquisa por Similaridade de Vetor</a></span></li>
#                     <ul class="toc-item">
#                         <li><span><a href="#Vetores-aleatorios" data-toc-modified-id="Vetores-aleatorios"><span class="toc-item-num">3.2.3.1 -&nbsp;&nbsp;</span>Vetores Aleatórios</a></span></li>
#                         <li><span><a href="#KNN" data-toc-modified-id="KNN"><span class="toc-item-num">3.2.3.2 -&nbsp;&nbsp;</span>O KNN</a></span></li>
#                         <li><span><a href="#Vetores-de-similaridade-com-BERT" data-toc-modified-id="Vetores-de-similaridade-com-BERT"><span class="toc-item-num">3.2.3.3 -&nbsp;&nbsp;</span>Vetores de Similaridade com BERT</a></span></li>
#                     </ul>
#                 </ul>
#             </ul>
#         </li>
#         <li><span><a href="#Conclusao" data-toc-modified-id="Conclusao"><span class="toc-item-num">4 -&nbsp;&nbsp;</span>Conclusão</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# <h1>Introdução<span id="Introducao"></span></h1>

# %% [markdown]
# <h2>Divisão de Trabalhos<span id="Divisao-de-trabalhos"></span></h2>
#
# Na realização deste trabalho:
#
# - A aluna Beatriz Santos contribuiu:
#     - no desenvolvimento do código inicial para a tarefa 1.
#     - na melhoria do código da tarefa 2.
#     - na escrita do relatório.
#
# - A aluna Manoela Azevedo contribuiu:
#     - na melhoria do código da tarefa 1 e colocação na máquina vitual.
#     - no desenvolvimento do código inicial para a tarefa 2.
#     - na escrita do relatório.
#
# Foi despendido, em média, um total de 20 horas para a realização deste projeto, de forma conjunta.

# %% [markdown]
# <h2>Declaração<span id="Declaracao"></span></h2>
#
# <i>
#     Nós, Beatriz Figueiredo dos Santos e Manoela Padilha Azevedo, estudantes com os números de inscrição 50473 e 50034 respetivamente, do 1º Ciclo em Informática Web, Móvel e na Nuvem da Universidade da Beira Interior, declaramos ter desenvolvido o presente trabalho e elaborado o presente texto em total consonância com o Código de Integridade da Universidade da Beira Interior. Mais concretamente afirmamos não ter incorrido em qualquer das variedades de Fraude Académica, e que aqui declaramos conhecer, que em particular atendemos à exigida referenciação de frases, extratos, imagens e outras formas de trabalho intelectual, e assumindo assim na íntegra as responsabilidades da autoria.
#   <br><br>
#     Universidade da Beira Interior,
#   <br>
#     Covilhã  18/04/2025
# </i>

# %% [markdown]
# <h2>Motivação<span id="Motivacao"></span></h2>
#
# Para o desenvolvimento deste projeto, foram aplicados em prática os conhecimentos adquiridos ao longo das aulas da unidade curricular,
# com o objetivo de aprofundar a compreensão sobre conceitos de aquisição, armazenamento e recuperação de dados em larga escala.
#
# Este trabalho contribuiu para o aprofundamento do conhecimento das alunas no que diz respeito ao funcionamento e aos desafios relacionados ao Web Scraping. Contribuiu também para uma melhor compreensão da recolha de grande quantidade de dados e tarefas como a indexação e a recuperação. Além disso, permitiu o contacto com novas ferramentas, como o sistema de armazenamento em memória Redis, e um aprofundamento na plataforma Docker.

# %% [markdown]
# <h1>Tarefa 1<span id="Tarefa-1"></span></h1>

# %% [markdown]
# <h2>Tarefa 1.1<span id="Tarefa-1.1"></span></h2>
# Para a realização desta tarefa, era necessário a seleção de uma ferramenta para o auxílio da aquisição de dados em larga escala. A ferramenta escolhida foi a metedologia de Web Scraping, lecionada durante as aulas.
#
# Já o website escolhido, o portal português da SAPO, apresentou-se como o mais bem avaliado para esse projeto. Foi escolhido especificamente a secção de "Últimas Notícias" (https://www.sapo.pt/noticias/ultimas), por ter um grande fluxo de notícias e uma boa estruturação HTML/CSS para o processo de recolha e sobre a distinção dos dados e artigos.
#
#
# O grupo precedeu então, ao desenvolvimento do código em linguagem Python para a recolha destes dados, usando como base código lecionado em aulas e produzindo um código final, testado inicialmente em Google Colaboratory, mas devido a uma maior complexidade no que diz respeito aos Logs, foi a seguir em sua maioria desenvolvido e testado em Jupyter Notebook.

# %%
import time
import json
import logging
from random import randint
import requests
from bs4 import BeautifulSoup

logging.basicConfig(
                    level=logging.INFO,
                    filename="logs.log",
                    filemode="w", 
                    format="%(asctime)s; Line:%(lineno)s; %(levelname)s: %(message)s",
                    datefmt="%d-%b-%Y %H:%M")

url = "https://www.sapo.pt/noticias/ultimas?pagina=1"
page = requests.get(url, headers={"User-Agent": "Defined"})
soup = BeautifulSoup(page.content, 'html.parser')

last_page = soup.find('li', class_='last-page')
if last_page:
    n_pages = int(last_page.get_text())
else:
    n_pages = 1

headers = {"User-Agent": "Mozilla/5.0"}
news_list = []
start_time = time.time()
run_time = 120 * 60 * 60  
news_id = 1

while time.time() - start_time < run_time:
    totalNews = 0

    for page_num in range(n_pages, 0, -1):
        url = f"https://www.sapo.pt/noticias/ultimas?pagina={page_num}"
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        articles = soup.find_all('article', class_='article')

        if not articles:
            logging.error("Nenhum artigo encontrado. Parando")
            break

        for article in articles:
            title_tag = article.find('h3', class_='title')
            title = title_tag.text.strip() if title_tag else "Sem título"

            date_tag = article.find('span', class_='date')
            date = date_tag.text.strip() if date_tag else "Sem data"

            summary_tag = article.find('div', class_='excerpt')
            summary = summary_tag.text.strip() if summary_tag else "Sem resumo"

            link_tag = article.find('a')
            link = link_tag['href'] if link_tag else "#"
            if not link.startswith("http"):
                link = "https://www.sapo.pt" + link

            img_tag = article.find('picture')
            img = img_tag['data-original-src'] if img_tag else None

            news_item = {
                'id': news_id,
                'page': page_num,
                'title': title,
                'date': date,
                'summary': summary,
                'url': link,
                'img': img
            }

            if not any(news['url'] == news_item['url'] for news in news_list):
                news_list.append(news_item)
                totalNews += 1
                news_id += 1

        time.sleep(randint(1, 3))

    with open("noticias.json", "w", encoding="utf-8") as f:
        json.dump(news_list, f, ensure_ascii=False, indent=4)

    if totalNews == 0:
      logging.warning("Nenhuma nova notícia encontrada.")
    
    logging.info(f"Atualização concluída! {totalNews} novas notícias adicionadas.")
    time.sleep(3600)

# %% [markdown]
# Uma das dificuldades encontradas, foi garantir a iteração das páginas de notícias na SAPO; Apesar do código buscar a última notícia por conceitos de eficácia, as páginas de notícias da SAPO seguem apenas até a décima página.
#
# A biblioteca `BeautifulSoup` é usada para extrair e manipular dados de ficheiros de forma simples e eficiente.
#
# Em cada percurso de extração, o código percorre as páginas e identifica os elementos 'article' extraindo a seguir os dados:
#  -título
#  -data (data e hora de publicação)
#  -resumo (pequena explicação sobre a notícia)
#  -url (o link da notícia)
#  -imagem ( o link para a imagem)
#
# Os dados são armazenados, primeiramente em um dicionário Python que depois é guardado em um ficheiro JSON, chamado de `noticias.json`. Para garantir a inexistência de repetições, foi usada uma verificação na URL.
#
# O processo é feito de novo a cada uma hora. O processo, como também definido no código, executou por 120 horas ou 5 dias.
#
# O código também define configurações relacionadas ao ficheiro de Logging. Este ficheiro será responsável por anotar todas as chamadas e a hora em que foram realizadas, bem como garantir se algum erro fosse encontrado. Tudo ficou armazendado em um ficheiro chamado `logs.log`.

# %% [markdown]
# O código correu em uma máquina virtual pessoal durante cinco dias ininterruptos, resultando na recolha de um total de 8.429 notícias.

# %% [markdown]
# <h2>Tarefa 1.2<span id="Tarefa-1.2"></span></h2>

# %% [markdown]
# Para a realização da tarefa 1.2, foi realizado um simples código que percorre os primeiros 5 elementos do ficheiro noticias.json

# %%
import json

with open("noticias.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Percorrer os 5 primeiros itens
for i, item in enumerate(data[:5], start=1):
    print(f"Notícia {i}:")
    print(item)
    print("-" * 40)
# Out:
# Notícia 1:
# {'id': 1, 'page': 10, 'title': 'Escritor angolano José Mendonça lamenta ausência de impacto da literatura na governação do país', 'date': '8 abr 2025 15:48', 'summary': 'O escritor e jornalista angolano, José Luís Mendonça, lamentou a ausência de impacto da literatura na governação de Angola e admitiu que já sofreu ameaças pelas opiniões e obras que publica. “Acho que tenho o direito de defender o meu povo. Nunca pertenci ao Governo, sempre fui um trabalhador, eu ch', 'url': 'https://www.sapo.pt/noticias/economia/escritor-angolano-jose-mendonca-lamenta_67f5378c01e7f30f40894ba8', 'img': 'https://forbesafricalusofona.com/wp-content/uploads/jose-luis-mendonca.jpg'}
# ----------------------------------------
# Notícia 2:
# ...

# %% [markdown]
# Percorrer os 10 primeiros Logs

# %% [markdown]
# Para incrementar também a tarefa, foi acrescentado uma breve visualização dos primeiros 10 logs.

# %%
with open("logs.log", "r", encoding="utf-8") as f:
    for i, linha in enumerate(f):
        if i >= 10:
            break
        print(f"Log {i + 1}: {linha.strip()}")
        print("-" * 40)
# Out:
# Log 1: 08-Apr-2025 16:16; Line:86; INFO: Atualização concluída! 225 novas notícias adicionadas.
# ----------------------------------------
# Log 2: 08-Apr-2025 17:17; Line:86; INFO: Atualização concluída! 123 novas notícias adicionadas.
# ----------------------------------------
# Log 3: 08-Apr-2025 18:17; Line:86; INFO: Atualização concluída! 104 novas notícias adicionadas.
# ----------------------------------------
# Log 4: 08-Apr-2025 19:18; Line:86; INFO: Atualização concluída! 96 novas notícias adicionadas.
# ----------------------------------------
# Log 5: 08-Apr-2025 20:18; Line:86; INFO: Atualização concluída! 63 novas notícias adicionadas.
# ----------------------------------------
# Log 6: 08-Apr-2025 21:18; Line:86; INFO: Atualização concluída! 54 novas notícias adicionadas.
# ----------------------------------------
# Log 7: 08-Apr-2025 22:19; Line:86; INFO: Atualização concluída! 59 novas notícias adicionadas.
# ----------------------------------------
# ...

# %% [markdown]
# <h1>Tarefa 2<span id="Tarefa-2"></span></h1>

# %% [markdown]
# O objetivo da segunda tarefa constituia no processo do armazenamento e recuperação desta grande quantidade de dados adquirida.
#
# Neste tópico, foi utilizado formas de indexação e pesquisa nesses dados armazenados. Para o auxílio dessas tarefas, foi recorrido à utilização do Redis, uma base de dados em memória do tipo chave-valor, que facilita o acesso aos dados em larga escala.
# O Redis foi executado através de um <i>container</i> Docker, com a sua configuração fornecida pelo docente em aula.
#
# A realização dessas pesquisas recorreu a métodos tradicionais através de módulos do redis como `RediSearch` o `Search`, `Queries` e uma experiência com o uso de vetores de similaridade (ou <i>`Embeddings`</i>)

# %% [markdown]
# <h2> Tarefa 2.1<span id="Tarefa-2.1"></span></h2>

# %% [markdown]
# Indexação dos Dados no Redis

# %%
from redis import Redis
from redis.commands.search.field import TextField
from redis.commands.search.indexDefinition import IndexDefinition, IndexType

# conexão do redis com o docker através do localhost
r = Redis(host='localhost', port=6379)

# %%
# cria uma função para criar um index
def create_index(r, index_name, doc_prefix, fields):    
    try:
        r.ft(index_name).info()
        print("Index already exists!")
    except:
        r.ft(index_name).create_index(fields=fields, definition=IndexDefinition(prefix=[doc_prefix]))
        
    print("Index created")

# %% [markdown]
# A função `create index` cria o índice usando a variável do nome `index_name`, `doc_prefix` para definir um prefixo para as chaves dos documentos e a variável `fields` para os campos que serão indexados.

# %%
#função pra receber o ficheiro
def index_documents(r, doc_prefix, documents):
    for i, doc in enumerate(documents):
        doc_cleaned = {key: (value if value is not None else "") for key, value in doc.items()}
        key = f"{doc_prefix}{str(i)}"
        r.hset(key, mapping=doc_cleaned)
    
    print("Documents indexed")

# %% [markdown]
# A função `index_documents` recebe o ficheiro JSON através de `documents`. A fuhnção percorre cada objeto dentro do ficheiro e substitui valores None por strings vazias, adiciona uma chave única para cada um. A seguir, a função `hset`, armazena esses documentos no Redis.

# %%
#importação do ficheiro noticias.json
import json

with open("noticias.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %% [markdown]
# Processo para a importação do ficheiro noticias.json que será utilizado ao longo do projeto como `data`.

# %%
index_name = 'idx:saponoticias'
doc_prefix = 'noticias:'

fields = (
    TextField("title"),
    TextField("summary"),
    TextField("date"),
    TextField("url"),
    TextField("img")
)

create_index(r, index_name, doc_prefix, fields)
index_documents(r, doc_prefix, data)
# Out:
# Index created
# Documents indexed

# %% [markdown]
# O processo de criação do índice é realizado, e ele pode ser visualizado na interface do Redis através da porta definida no localhost.

# %% [markdown]
# <h2>Tarefa 2.2<span id="Tarefa-2.2"></span></h2>
#
# Recuperação dos Dados

# %% [markdown]
# Neste projeto, a tarefa de recuperação de dados refere-se ao ato de localizar e extrair informações importantes a partir de um índice de informações.

# %% [markdown]
# <h3>Pesquisa Tradicional<span id="Pesquisa-tradicional"></span></h3>

# %% [markdown]
# Na pesquisa tradicional, foi usado código simples, apenas com recurso ao módulo Search do Redis.

# %%
from redis.commands.search import Search

# %% [markdown]
# Visualizar a quantidade de dados carregados no Redis, devem ser 8429 após o processo de indexação ser concluído.

# %%
results = r.ft(index_name).search("@*")
results.total
# Out:
# 8429

# %%
results = r.ft(index_name).search("@*")
results
# Out:
# Result{8429 total, docs: [Document {'id': 'noticias:3', 'payload': None, 'date': '8 abr 2025 15:48', 'img': 'https://media-manager.noticiasaominuto.com/1920/naom_67f532be2d860.jpg?crop_params=eyJwb3J0cmFpdCI6eyJjcm9wV2lkdGgiOjg5NiwiY3JvcEhlaWdodCI6MTU5NCwiY3JvcFgiOjYxOSwiY3JvcFkiOjEwM319', 'page': '10', 'url': 'https://www.sapo.pt/noticias/lifestyle/esta-quase-na-hora-do-lanche-e-vai-querer-ter_67f5380da88f780f2ef874c0', 'title': 'Está quase na hora do lanche e vai querer ter à mesa estas panquecas', 'summary': 'Fazem-se em poucos minutos. Bom apetite.'}, Document {'id': 'noticias:15', 'payload': None, 'date': '8 abr 2025 15:41', 'img': 'https://cdn.record.pt/images/2025-04/originalsizeuu2025-04-08-14-40-38-2354800.jpg', 'page': '10', 'url': 'https://www.sapo.pt/noticias/desporto/nuno-borges-na-segunda-ronda-em-monte-carlo_67f53738fde9370f3a550734', 'title': 'Nuno Borges na segunda ronda em Monte Carlo após desistência de Rune', 'summary': 'Português vencia por 6-2 e 3-0 quando o din
# ...

# %% [markdown]
# Esse código realiza uma pesquisa no índice especificado (`index_name`) para retornar todos os documentos disponíveis, utilizando o termo `@*`.

# %%
results = r.ft(index_name).search("Tecnologia")
results
# Out:
# Result{78 total, docs: [Document {'id': 'noticias:367', 'payload': None, 'date': '8 abr 2025 18:18', 'img': 'http://eco.imgix.net/uploads/2025/04/cropped-minecraft.jpg', 'page': '5', 'url': 'https://eco.sapo.pt/2025/04/08/minecraft-usa-tecnologia-da-portuguesa-sound-particles/', 'title': 'Minecraft usa tecnologia da portuguesa Sound Particles', 'summary': 'A tecnologia da startup, sedeada em Leiria, já tinha sido usada em grandes produções, como Oppenheimer, Missão Impossível, Indiana Jones ou Dune.'}, Document {'id': 'noticias:1061', 'payload': None, 'date': '9 abr 2025 09:19', 'img': 'https://mb.web.sapo.io/fd181930ca5c492f34fc69320a11bbbf000facad.jpg', 'page': '1', 'url': 'https://mag.sapo.pt/cinema/atualidade-cinema/artigos/um-filme-minecraft-usou-tecnologia-audio-portuguesa-da-sound-particles', 'title': '"Um filme Minecraft" usou tecnologia áudio portuguesa da Sound Particles', 'summary': 'Tecnologia inovadora que permite criar “sons tridimensionais complexos e realistas” é de u
# ...

# %% [markdown]
# Esse código realiza uma pesquisa no índice para retornar todos os documentos que contêm o termo "Tecnologia", as palavras-chaves podem ser alteradas para corresponder à pesquisa de diferentes temas.

# %% [markdown]
# Entretanto o Redis, por padrão, limita o número de resultados retornados para 10, a menos que seja especificado um valor diferente.

# %% [markdown]
# Se for necessário específicar esse valor, é necessário recorrer às Queries.

# %% [markdown]
# <h3>Pesquisa com Queries<span id="Pesquisa-com-queries"></span></h3>

# %% [markdown]
# As Queries são comandos que podem ser utilizados para buscar informações mais específicas no índice.

# %%
from redis.commands.search.query import Query

# %%
query = Query("@*").paging(0, 300)
results = r.ft(index_name).search(query)

for doc in results.docs:   
    print(f"{doc['id']}")
    print(f"Título: {doc['title']}")
    print(f"Resumo: {doc['summary']}")
    print(f"Data: {doc['date']}")
    print(f"URL: {doc['url']}")
    print(f"URL Imagem: {doc['img']}")
    print("\n")
# Out:
# noticias:3
# Título: Está quase na hora do lanche e vai querer ter à mesa estas panquecas
# Resumo: Fazem-se em poucos minutos. Bom apetite.
# Data: 8 abr 2025 15:48
# URL: https://www.sapo.pt/noticias/lifestyle/esta-quase-na-hora-do-lanche-e-vai-querer-ter_67f5380da88f780f2ef874c0
# URL Imagem: https://media-manager.noticiasaominuto.com/1920/naom_67f532be2d860.jpg?crop_params=eyJwb3J0cmFpdCI6eyJjcm9wV2lkdGgiOjg5NiwiY3JvcEhlaWdodCI6MTU5NCwiY3JvcFgiOjYxOSwiY3JvcFkiOjEwM319
#
#
# noticias:15
# Título: Nuno Borges na segunda ronda em Monte Carlo após desistência de Rune
# Resumo: Português vencia por 6-2 e 3-0 quando o dinamarquês tomou a decisão de não continuar
# Data: 8 abr 2025 15:41
# URL: https://www.sapo.pt/noticias/desporto/nuno-borges-na-segunda-ronda-em-monte-carlo_67f53738fde9370f3a550734
# URL Imagem: https://cdn.record.pt/images/2025-04/originalsizeuu2025-04-08-14-40-38-2354800.jpg
#
#
# noticias:29
# ...

# %% [markdown]
# Neste exemplo, uma query é criada para buscar todos os documentos no índice especificado (index_name) com o termo @*,
# utilizando a paginação para retornar os primeiros 300 resultados. Exibe as informações de forma mais organizada.

# %%
query = Query("title: 'Portugal'").paging(0, 50)
results = r.ft(index_name).search(query)

for doc in results.docs:   
    print(f"{doc['id']}")
    print(f"Título: {doc['title']}")
    print(f"Resumo: {doc['summary']}")
    print(f"Data: {doc['date']}")
    print(f"URL: {doc['url']}")
    print(f"URL Imagem: {doc['img']}")
    print("\n")

# %% [markdown]
# Neste exemplo, utiliza-se um filtro para as informações que tenham "Portugal" no título e restringe os primeiros 50 resultados.
#
# É possível remover todo o conteúdo do Redis

# %%
#remover tudo do redis
r.flushall()
# Out:
# True

# %% [markdown]
# Recomenda-se a execução da remoção para dar continuidade às experiências.

# %% [markdown]
# <h3> Pesquisa por Similaridade de Vetor<span id="Pesquisa-por-similaridade-de-vetor"></span></h3>

# %% [markdown]
# Pequena explicação sobre o que é o Vetor

# %% [markdown]
# <h4>Vetores Aleatórios<span id="Vetores-aleatorios"></span></h4>

# %% [markdown]
# Os vetores aleatórios (ou <i>`dummy vectors`</i>) são sequências de números gerados de forma aleatória.
# Esses números aqui, serão usados para simular os `embeddings` reais, e a forma como palavras e termos com significados semelhantes ficam próximas em um espaço vetorial.

# %%
import numpy as np

for content in data:
    content['title_emb'] = np.random.rand(1536).astype(np.float32)  # Vetor aleatório de 1536 dimensões

# %% [markdown]
# O código cria um vetor aleatório para cada item de "data" e para cada conteúdo na lista de dados, ele gera um vetor com 1536 números aleatórios (entre 0 e 1) e os armazena como um novo campo chamado `'title_emb'`. O valor 1536 é uma dimensão padrão em modelos de geração de embeddings.

# %%
import numpy as np

def index_documents_with_vectors(r, doc_prefix, documents, *vector_fields):
    for i, doc in enumerate(documents):
        key = f"{doc_prefix}:{i}"
        
        for field, value in doc.items():
            if isinstance(value, np.ndarray):
                doc[field] = value.tobytes()
            elif value is None:
                doc[field] = ""
            elif isinstance(value, str):
                doc[field] = value.encode('utf-8')
            elif isinstance(value, bytes):
                pass  # já está OK
            else:
                doc[field] = str(value).encode('utf-8') 

        r.hset(key, mapping=doc)
    
    print("Documents indexed.")

# %% [markdown]
# Para lidar com vetores, é necessário fazer alterações na forma com que o índice é criado. Essas mudanças incluem a transformação dos vetores, representados como arrays do NumPy, em bytes antes de serem armazenados no Redis, utilizando a função `tobytes().`

# %%
import numpy as np
import redis
from redis.commands.search.field import TextField, NumericField, VectorField  

#nome do índice
index_name = 'idx:dummyTest'
# prefixo chaves para os documentos
doc_prefix = 'dummydoc:'  

vector_field = 'title_emb'  # nome do campo que contém os vetores
VECTOR_DIM = len(data[0][vector_field])  # dimensão dos vetores
VECTOR_NUMBER = len(data)  # número de documentos
DISTANCE_METRIC = "COSINE"  # métrica de distância (COSINE, IP, L2)

# defenição dos campos do índice no Redis
url = TextField(name="url")
title = TextField(name="title")
title_emb = VectorField(vector_field,
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)

fields = [url, title, title_emb]


# criação do indice no Redis
create_index(r, index_name, doc_prefix, fields)

# indexação dos documentos no Redis
index_documents_with_vectors(r, doc_prefix, data, vector_field)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 31
#      27 fields = [url, title, title_emb]
#      30 # criação do indice no Redis
# ---> 31 create_index(r, index_name, doc_prefix, fields)
#      33 # indexação dos documentos no Redis
#      34 index_documents_with_vectors(r, doc_prefix, data, vector_field)
#
# NameError: name 'create_index' is not defined

# %% [markdown]
# Aqui é feita a criação do Índice apropriado para o uso de vetores, contendo campos de configuração e informação dos vetores e o campo `VectorField` que define os campos que existirão no índice.

# %% [markdown]
# <h4> O KNN <span id="KNN"></span></h4>

# %% [markdown]
# O KNN (K-Nearest Neighbors) é um algoritmo de aprendizado de máquina.
# Aqui, ele será utilizado para encontrar documentos similares a um dado vetor, comparando distâncias dos vetores armazenados previamente no Redis.

# %%
def search_redis(index_name, k, vector_field, return_fields, hybrid_fields = "*"):
   
    #get embeddings of a hyphotetical query
    query_emb = np.random.rand(1536)
    
    # Prepare the Query
    query = (
        Query(f"{hybrid_fields}=>[KNN {k} @{vector_field} $vector as score]")
         .return_fields(*return_fields)
         .sort_by("score")
         .paging(0, k)
         .dialect(2)
    )

    query_params = {"vector": np.array(query_emb, dtype=np.float32).tobytes()}

    # perform vector search
    results = r.ft(index_name).search(query, query_params)
    return results.docs

# %%
k = 5
vector_field = "title_emb"
return_fields = ["id", "url", "title", "score"]
index_name = 'idx:dummyTest' #the name of the index, which you will use when doing queries

results = search_redis(index_name, k, vector_field, return_fields)
for doc in results:
    score = 1 - float(doc['score'])
    print(f"{doc['title']}; score:{score:.3f}")
    print(f"{doc['url']}")
    print("\n")
# Out:
# Autarquia procura medidas mais eficazes ao combate de consumo de álcool na via pública; score:0.779
# https://cidadedoporto.sapo.pt/noticias/autarquia-procura-medidas-mais-eficazes-ao-combate-de-consumo-de-alcool-na-via-publica-1744188513
#
#
# Sabe quais são as melhores vitaminas para o seu tipo pele?; score:0.778
# https://www.sapo.pt/noticias/lifestyle/sabe-quais-sao-as-melhores-vitaminas-para-o_67f9916883fde50f17cae660
#
#
# Mina de sal-gema de Loulé acolhe instalações de três artistas a partir de dia 17; score:0.777
# https://www.sapo.pt/noticias/atualidade/mina-de-sal-gema-de-loule-acolhe-instalacoes-_67f56aa183fde50f17cac5ba
#
#
# A Branca de Neve foi o segundo filme da Disney com mais emissões de carbono atrás da Pequena Sereia; score:0.777
# https://sustentix.sapo.pt/a-branca-de-neve-foi-o-segundo-filme-da-disney-com-mais-emissoes-de-carbono-atras-da-pequena-sereia/
#
#
# “Os Metallica Salvaram-me a Vida”: vem aí um novo documentário sobre os fãs da banda; score:0.776
# ...

# %% [markdown]
# Esta etapa define a função `search_redis` e a executa no índice criado anteriormente, é gerado um vetor de consulta aleatório e a seguir devolve os 5
# documentos mais semelhantes de acordo com esse vetor, ordenados pela pontuação (ou <i>`score`</i>) de similaridade.

# %% [markdown]
# Com este processo, é possível confirmar o funcionamento dos vetores e seu cálculo, embora os resultados sejam aleatórios. Mesmo assim, é possível entender como o sistema lida com os vetores e como o processo de busca vetorial ocorre.

# %%
#remover tudo do redis
r.flushall()
# Out:
# True

# %% [markdown]
# Novamente, recomenda-se a execução da remoção para dar continuidade à última experiência.

# %% [markdown]
# <h4> Vetores de Similaridade com BERT<span id="Vetores-de-similaridade-com-BERT"></span></h4>

# %% [markdown]
# BERT ou SBERT (Bidirectional Encoder Representations from Transformers) é um modelo de linguagem usado para gerar representações de texto em
# forma de vetores de alta dimensão.
# Aqui, ele será utilizado para criar vetores reais, que representem os títulos das notícias e realizar buscas por similaridade entre eles.

# %%
# !pip install redis numpy torch transformers --quiet

# %%
#verificar daqui o que precisa de novo ou não:
import torch
from transformers import AutoTokenizer, AutoModel

# %%
# !pip install hf_xet
# Out:
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 1.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.0/4.1 MB 1.3 MB/s eta 0:00:03
#    ------------ --------------------------- 1.3/4.1 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.1 MB 1.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.8/4.1 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.4/4.1 MB 1.5 MB/s eta 0:00:02
#    ------------------------- -------------- 2.6/4.1 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 2.9/4.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 1.5 MB/s eta 0:00:01
# ...

# %%
from transformers import AutoTokenizer, AutoModel

model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Adicionando from_tf=False
model = AutoModel.from_pretrained(model_name, from_tf=False)

# %% [markdown]
# Esse código carrega o modelo "paraphrase-multilingual-MiniLM-L12-v2" da biblioteca `transformers`.
# Foi escolhido para a realização desta tarefa por ser adaptado para o português.

# %%
def get_embeddings_bert(text, tokenizer, model):
    tokens = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        output = model(**tokens)
    embeddings = output.last_hidden_state.mean(dim=1)
    return embeddings[0].numpy()

# %% [markdown]
# Essa função gera embeddings (representações vetoriais) para um texto usando o modelo BERT, processando o texto com um tokenizador
# e retornando a média dos vetores das últimas camadas do modelo.

# %%
def create_vector_index(r, index_name, prefix, dim, vector_field):
    try:
        r.ft(index_name).info()
        print("Index already exists.")
    except:
        fields = [
            TextField("title"),
            TextField("summary"),
            TextField("url"),
            VectorField(vector_field,
                        "FLAT", {
                            "TYPE": "FLOAT32",
                            "DIM": dim,
                            "DISTANCE_METRIC": "COSINE"
                        })
        ]
        r.ft(index_name).create_index(fields=fields, definition=IndexDefinition(prefix=[prefix], index_type=IndexType.HASH))
        print("Vector index created.")

# %% [markdown]
# O novo índice é ajustado para armazenar vetores gerados por BERT, utilizando a métrica de similaridade `COSINE` e um vetor de dimensão especificada.
# Ele foi programado para armazenar os campos, `tittle`, `summary` e `url`, junto com o vetor de similaridade.

# %%
def index_documents_with_bert_vectors(r, docs, prefix, vector_field):
    for i, doc in enumerate(data):
        emb = get_embeddings_bert(doc["title"] + " " + doc["summary"], tokenizer, model)
        r.hset(f"{prefix}{i}", mapping={
            "title": doc["title"],
            "summary": doc.get("summary", ""),
            "url": doc.get("url", ""),
            vector_field: emb.astype(np.float32).tobytes()
        })
    print("Documents indexed with embeddings.")

# %%
# alterar para search_vector_redis, para não entrar em conflito com o anterior
def search_redis_bert(query_emb, index_name, k, vector_field, return_fields):
    query_vector = np.array(query_emb, dtype=np.float32).tobytes()
    base_query = f'*=>[KNN {k} @{vector_field} $vector AS score]'
    query = Query(base_query).return_fields(*return_fields).sort_by("score").dialect(2)
    params = {"vector": query_vector}
    results = r.ft(index_name).search(query, params)
    return results.docs

# %% [markdown]
# A função `index_documents_with_bert_vectors` indexa documentos no Redis, gerando embeddings com BERT para cada título e resumo,
# e os armazena junto com outros campos como título, resumo e URL. Já a função `search_redis_bert` realiza uma busca no índice,
# comparando a consulta com os embeddings dos documentos utilizando KNN para encontrar os mais similares e retornando os resultados ordenados pelo score.

# %%
# acho que pode ser removido
import json

with open("noticias.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
# cria o índice e indexa os dados com os vetores BERT
index_name = "idx:vectorBERT"
prefix = "docBERT:"
vector_field = "title_emb"
dim = 384  

# cria índice e indexar dados
create_vector_index(r, index_name, prefix, dim, vector_field)
index_documents_with_bert_vectors(r, data, prefix, vector_field)
# Out:
# Vector index created.
# Documents indexed with embeddings.

# %% [markdown]
# Este código, cria um índice no Redis e indexa documentos com vetores BERT para similaridade.

# %%
query = "Música "
query_emb = get_embeddings_bert(query, tokenizer, model)
results = search_redis_bert(query_emb, index_name, 3, vector_field, ["title", "url", "summary", "score"])

for doc in results:
    score = 1 - float(doc.score)
    print(f"{doc['title']} (score: {score:.3f})")
    print(doc['url'])
    print(doc['summary'])
    print("-" * 50)
# Out:
# Famalicão: Música em destaque na Casa do Artista Amador, este fim de semana (score: 0.642)
# https://cidadehoje.sapo.pt/famalicao-musica-em-destaque-na-casa-do-artista-amador-este-fim-de-semana/
# A programação para sexta-feira e sábado
# --------------------------------------------------
# Existe música de 1-bit? Sim, e um dos seus mestres toca esta semana no Porto (score: 0.561)
# https://www.sapo.pt/noticias/entretenimento/existe-musica-de-1-bit-sim-e-um-dos-seus_67f542ae01e7f30f40894c1a
# O norte-americano Tristan Perich virá ao Porto apresentar as obras “Open Symmetry” e “Infinity Gradient”, que é considerado o seu trabalho de maior escala até hoje: um concerto para órgão de tubos e cem colunas de som. Pormenor: esta música eletrónica é desenvolvida com base em apenas 1-bit, a unida
# --------------------------------------------------
# 15 novos artistas que estão a marcar a música portuguesa em 2025 (score: 0.529)
# ...

# %% [markdown]
# Este código mostra o resultado mais interessante do projeto, retornando as notícias mais relevantes com base
# na similaridade entre a consulta fornecida e os vetores de embedding armazenados.
#
# Consultas mais genéricas costumam resultar em pontuações mais baixas, algumas vezes os resultados assemelham-se muito pouco.
# A seguir estão algumas sugestões de palavras-chave com bons índices de similaridade e interesse, considerando o meio noticioso português a altura da coleta das informações:
# - Páscoa
# - Benfica
# - Universidade
# - Trump

# %% [markdown]
# <h1>Conclusão<span id="Conclusão"></span></h1>

# %% [markdown]
# Ao longo deste projeto, foi possível aplicar conceitos práticos de ciência de dados em larga escala, desde a manipulação e análise inicial dos dados até a execução de tarefas mais complexas em diferentes ambientes. As tarefas propostas pelo docente permitiram consolidar conhecimentos sobre a realização de diferentes tarefas em um contexto, antes nunca realizado pelas alunas, de grande volume de dados.
#
# Através da divisão equilibrada das responsabilidades, foi possível explorar diferentes funcionalidades, contribuindo para a conclusão dos resultados e o enriquecimento da aprendizagem conjunta.
#
# Como trabalho futuro, considera-se interessante aprofundar a coleta de mais conteúdos de dados, como não só os artigos o título e resumo dos artigos,  mas também todo o seu conteúdo interno de texto. Realização de Queries e pesquisas mais complexas, assim como o aprendizado e uso do modelo Openai para para vetorização e análise semântica dos dados.
